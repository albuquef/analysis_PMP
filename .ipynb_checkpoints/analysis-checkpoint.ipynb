# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
PATH_DATA='tables_2/'

df_mat_p_26_arrond = pd.read_csv(PATH_DATA+'reports_mat_p_26_cover_arrond.csv')
df_mat_p_42_arrond = pd.read_csv(PATH_DATA+'reports_mat_p_42_cover_arrond.csv')
df_mat_p_51_epci = pd.read_csv(PATH_DATA+'reports_mat_p_51_cover_epci.csv')
df_mat_p_62_epci = pd.read_csv(PATH_DATA+'reports_mat_p_62_cover_epci.csv')

df_urgenc_p_42_arrond = pd.read_csv(PATH_DATA+'reports_urgenc_p_42_cover_arrond.csv')
df_urgenc_p_66_arrond = pd.read_csv(PATH_DATA+'reports_urgenc_p_66_cover_arrond.csv')
df_urgenc_p_54_epci = pd.read_csv(PATH_DATA+'reports_urgenc_p_54_cover_epci.csv')
df_urgenc_p_78_epci = pd.read_csv(PATH_DATA+'reports_urgenc_p_78_cover_epci.csv')

# %%
df_mat_p_26_arrond
# Out:
#    exact_notimelimit_sol exact_notimelimit_time      exact_TL_sol  \
# 0       238284444,338007       44,4203910827637  238284444,338007
# 1       238284444,338007        86,296599149704  238284444,338007
# 2       238284444,338007       85,1924648284912  238284444,338007
# 3       238284444,338007       136,066453933716  238284444,338007
# 4       238284444,338007       166,965092897415  117984691,578817
# 5       238284444,338007       205,278450012207  117984691,578817
# 6       117984691,578817        273,05664896965  117984691,578817
# 7       117984691,578817        348,36289191246  108918377,701754
# 8       117984691,578817       486,051553010941  97498258,8108969
# 9       108918377,701754       670,719871997833  97498258,8108969
# 10      100079245,457949       928,642953872681  97498258,8108969
# 11      100079245,457949       1015,48322796822  97498258,8108969
# 12      100079245,457949       1133,33673286438  97498258,8108969
# 13      100079245,457949       1361,06894493103  97498258,8108969
# 14      100079245,457949        1690,3384718895  97498258,8108969
# 15      100079245,457949       2053,48634195328  97498258,8108969
# 16      100079245,457949        2598,6722137928  97498258,8108969
# 17      100079245,457949       3020,37793684006  97498258,8108969
# 18      100079245,457949       3851,75243902206               NaN
# 19      100079245,457949       4625,25369501114               NaN
# 20      100079245,457949       5253,61859989166               NaN
# 21      77355879,3530546       7809,31185984612               NaN
# 22      74831950,2531145        8782,5411298275               NaN
# 23      74831950,2531145       10161,9883768559               NaN
# 24      71059245,6172347       11623,5734059811               NaN
# 25      71059245,6172347        15519,315792799               NaN
# 26      71059245,6172347       17827,9029638767               NaN
# 27      71059245,6172347       20529,8929657936               NaN
# 28      71059245,6172347        23154,106580019               NaN
# 29      71059245,6172347       26231,5171518326               NaN
# 30      71059245,6172347       27899,4539139271               NaN
# 31      71059245,6172347       29375,7263917923               NaN
# 32      71059245,6172347       32156,3651549816               NaN
# 33      71059245,6172347       35737,9571959972               NaN
# 34      71059245,6172347       38314,1037049293               NaN
# 35      71059245,6172347       40369,8005440235               NaN
# 36      71059245,6172347       41933,5048179627               NaN
# 37      71059245,6172347       43760,8850970268               NaN
# 38      71059245,6172347       45968,0708918572               NaN
# 39      71059245,6172347       48562,4542310238               NaN
# 40      71059245,6172347       50456,6939380169               NaN
# 41      71059245,6172347       53118,9616289139               NaN
# 42      71059245,6172347        54212,190871954               NaN
# 43      67835508,8694892       62413,4704098702               NaN
# 44      67835508,8694892       62422,3217868805               NaN
# 45      67835508,8694892       63088,1955108643               NaN
# 46      67835508,8694892        74092,677793026               NaN
# 47      67835508,8694892        81569,052312851               NaN
# 48      67835508,8694892       89175,8212878704               NaN
# 49      67835508,8694892        104736,97318697               NaN
# 50      67835508,8694892       107664,331512928               NaN
# 51      67835508,8694892       142099,305567026               NaN
# 52      67818164,8187672       147887,264277935               NaN
# 53      67818164,8187672        152231,69334197               NaN
# 54      67818164,8187672       210825,813421965               NaN
# 55      67818164,8187672       230398,672299862               NaN
# 56      67818164,8187672        255492,66118288               NaN
# 57      67818164,8187672       278591,129289866               NaN
# 58      67818164,8187672       337665,925571918               NaN
#
#        exact_TL_time rssv_tbPMP_exact_sol rssv_tbPMP_exact_time  \
# 0   57,6610989570618     185409149,014781      30,9767091274261
# 1   84,9293899536133     185409149,014781      38,2813611030579
# 2    102,64398598671     114175842,524567      46,8869121074677
# 3   126,912235975266     104036897,915314      72,3426821231842
# 4   170,975170135498     104036897,915314      78,2181620597839
# 5   209,333559036255     104036897,915314      87,7372379302978
# 6    287,60701918602     94324839,8286978      100,932801961899
# 7   406,155730962753     86176506,1311239      146,621348142624
# 8   586,619023084641     86176506,1311239      159,799026966095
# 9   627,027538061142     79362688,1328418      181,231991052628
# 10  713,153244972229     79362688,1328418      204,880686998367
# 11  986,455450057983     79362688,1328418      229,462819099426
# 12  1218,74744915962     75422808,6253633      257,474583148956
# 13  1523,53844714165     75422808,6253633      367,033338069916
# 14  1984,39582109451     75422808,6253633      402,403455018997
# 15  2288,56130003929     75422808,6253633      450,942880153656
# 16  3048,56929802895     75422808,6253633      501,080961942673
# 17              3600     75422808,6253633       556,63810300827
# 18               NaN     75422808,6253633      619,120394945145
# 19               NaN     75422808,6253633      674,541334152222
# 20               NaN     75422808,6253633      735,004759073258
# 21               NaN     75422808,6253633      789,628239154816
# 22               NaN     75422808,6253633      840,452829122543
# 23               NaN     75422808,6253633      889,319327116013
# 24               NaN     75422808,6253633      958,125303030014
# 25               NaN     75422808,6253633      1014,54949498177
# 26               NaN     75422808,6253633      1080,29145908356
# 27               NaN     75422808,6253633      1145,45725393295
# 28               NaN     75422808,6253633      1199,54436206818
# 29               NaN     75422808,6253633      1251,96958398819
# 30               NaN     75422808,6253633      1299,12919306755
# 31               NaN     75422808,6253633       1347,9413459301
# 32               NaN     75422808,6253633        1397,332914114
# 33               NaN     75422808,6253633      1443,86234593391
# 34               NaN     75422808,6253633      1499,03372311592
# 35               NaN     75422808,6253633      1548,91594195366
# 36               NaN     75422808,6253633      1597,91437005997
# 37               NaN     75422808,6253633      1657,25154399872
# 38               NaN     71279281,5175249      2637,18239712715
# 39               NaN     71279281,5175249      2644,11435508728
# 40               NaN     71279281,5175249      2704,33346009254
# 41               NaN     71279281,5175249      2814,41742897034
# 42               NaN     71279281,5175249      2888,41274809837
# 43               NaN     71279281,5175249      2947,45169711113
# 44               NaN     71279281,5175249       3053,7885890007
# 45               NaN     71279281,5175249      3097,25968194008
# 46               NaN     71279281,5175249      3129,66367411613
# 47               NaN     71279281,5175249      3147,92367506027
# 48               NaN     71279281,5175249      3191,66370892525
# 49               NaN     71279281,5175249      3605,44595503807
# 50               NaN                  NaN                   NaN
# 51               NaN                  NaN                   NaN
# 52               NaN                  NaN                   NaN
# 53               NaN                  NaN                   NaN
# 54               NaN                  NaN                   NaN
# 55               NaN                  NaN                   NaN
# 56               NaN                  NaN                   NaN
# 57               NaN                  NaN                   NaN
# 58               NaN                  NaN                   NaN
#
#    rssv_tbPMP_exact-vns_sol rssv_tbPMP_exact-vns_time
# 0          75422808,6253633                         0
# 1          74302539,2715604           554,79199886322
# 2          73990592,7914798           971,38764500618
# 3          73942961,1472629          1499,31130981445
# 4          73942961,1472629          3370,32078194618
# 5                       NaN                       NaN
# 6                       NaN                       NaN
# 7                       NaN                       NaN
# 8                       NaN                       NaN
# 9                       NaN                       NaN
# 10                      NaN                       NaN
# 11                      NaN                       NaN
# 12                      NaN                       NaN
# 13                      NaN                       NaN
# 14                      NaN                       NaN
# 15                      NaN                       NaN
# 16                      NaN                       NaN
# 17                      NaN                       NaN
# 18                      NaN                       NaN
# 19                      NaN                       NaN
# 20                      NaN                       NaN
# 21                      NaN                       NaN
# 22                      NaN                       NaN
# 23                      NaN                       NaN
# 24                      NaN                       NaN
# 25                      NaN                       NaN
# 26                      NaN                       NaN
# 27                      NaN                       NaN
# 28                      NaN                       NaN
# 29                      NaN                       NaN
# 30                      NaN                       NaN
# 31                      NaN                       NaN
# 32                      NaN                       NaN
# 33                      NaN                       NaN
# 34                      NaN                       NaN
# 35                      NaN                       NaN
# 36                      NaN                       NaN
# 37                      NaN                       NaN
# 38                      NaN                       NaN
# 39                      NaN                       NaN
# 40                      NaN                       NaN
# 41                      NaN                       NaN
# 42                      NaN                       NaN
# 43                      NaN                       NaN
# 44                      NaN                       NaN
# 45                      NaN                       NaN
# 46                      NaN                       NaN
# 47                      NaN                       NaN
# 48                      NaN                       NaN
# 49                      NaN                       NaN
# 50                      NaN                       NaN
# 51                      NaN                       NaN
# 52                      NaN                       NaN
# 53                      NaN                       NaN
# 54                      NaN                       NaN
# 55                      NaN                       NaN
# 56                      NaN                       NaN
# 57                      NaN                       NaN
# 58                      NaN                       NaN

# %%
df = df_mat_p_26_arrond
p = 26
cover = 'arrond'
# df.plot(x='time_exact', y='sol_exact', kind='line')
# plt.plot(df.exact_time, df.exact_sol, color='red', label='Exact',linestyle="--")
plt.plot(df.exact_TL_time, df.exact_TL_sol, color='red', label='Exact')
plt.plot(df.rssv_tbPMP_exact_time, df.rssv_tbPMP_exact_sol, color='blue', label='RSSV-exact')
# plt.plot(df.rssv_tbPMP_exact_vns_time, df.rssv_tbPMP_exact_vns_sol, color='green', label='RSSV-exact-vns')



# Add labels and legend
plt.xlabel('Real Time')
plt.ylabel('FO')
plt.legend()
plt.title(f'Maternity p = {p} cover {cover} (18)')

# Save the plot as a PDF file
plt.savefig(f'maternity_plot_p_{p}_{cover}.pdf')

# Show the plot (optional)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f9bb4e9c403e> in <module>
#       4 # df.plot(x='time_exact', y='sol_exact', kind='line')
#       5 # plt.plot(df.exact_time, df.exact_sol, color='red', label='Exact',linestyle="--")
# ----> 6 plt.plot(df.exact_TL_time, df.exact_TL_sol, color='red', label='Exact')
#       7 plt.plot(df.rssv_tbPMP_exact_time, df.rssv_tbPMP_exact_sol, color='blue', label='RSSV-exact')
#       8 # plt.plot(df.rssv_tbPMP_exact_vns_time, df.rssv_tbPMP_exact_vns_sol, color='green', label='RSSV-exact-vns')
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     392
#     393         if self.axes.xaxis is not None:
# --> 394             self.axes.xaxis.update_units(x)
#     395         if self.axes.yaxis is not None:
#     396             self.axes.yaxis.update_units(y)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in update_units(self, data)
#    1464         neednew = self.converter != converter
#    1465         self.converter = converter
# -> 1466         default = self.converter.default_units(data, self)
#    1467         if default is not None and self.units is None:
#    1468             self.set_units(default)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/category.py in default_units(data, axis)
#     105         # the conversion call stack is default_units -> axis_info -> convert
#     106         if axis.units is None:
# --> 107             axis.set_units(UnitData(data))
#     108         else:
#     109             axis.units.update(data)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/category.py in __init__(self, data)
#     174         self._counter = itertools.count()
#     175         if data is not None:
# --> 176             self.update(data)
#     177
#     178     @staticmethod
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/category.py in update(self, data)
#     209         for val in OrderedDict.fromkeys(data):
#     210             # OrderedDict just iterates over unique values in data.
# --> 211             cbook._check_isinstance((str, bytes), value=val)
#     212             if convertible:
#     213                 # this will only be called so long as convertible is True.
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _check_isinstance(_types, **kwargs)
#    2244     for k, v in kwargs.items():
#    2245         if not isinstance(v, types):
# -> 2246             raise TypeError(
#    2247                 "{!r} must be an instance of {}, not a {}".format(
#    2248                     k,
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %%
df = df_mat_p_42_arrond
p = 42
cover = 'arrond'
# df.plot(x='time_exact', y='sol_exact', kind='line')
# plt.plot(df.exact_time, df.exact_sol, color='red', label='Exact',linestyle="--")
plt.plot(df.exact_TL_time, df.exact_TL_sol, color='red', label='Exact')
plt.plot(df.rssv_tbPMP_exact_time, df.rssv_tbPMP_exact_sol, color='blue', label='RSSV-exact')
# plt.plot(df.rssv_tbPMP_exact_vns_time, df.rssv_tbPMP_exact_vns_sol, color='green', label='RSSV-exact-vns')



# Add labels and legend
plt.xlabel('Real Time')
plt.ylabel('FO')
plt.legend()
plt.title(f'Maternity p = {p} cover {cover} (18)')

# Save the plot as a PDF file
plt.savefig(f'maternity_plot_p_{p}_{cover}.pdf')

# Show the plot (optional)
plt.show()

# %%
df = df_mat_p_51_epci
p = 51
cover = 'epci'
# df.plot(x='time_exact', y='sol_exact', kind='line')
# plt.plot(df.exact_time, df.exact_sol, color='red', label='Exact',linestyle="--")
plt.plot(df.exact_TL_time, df.exact_TL_sol, color='red', label='Exact')
plt.plot(df.rssv_tbPMP_exact_time, df.rssv_tbPMP_exact_sol, color='blue', label='RSSV-exact')
# plt.plot(df.rssv_tbPMP_exact_vns_time, df.rssv_tbPMP_exact_vns_sol, color='green', label='RSSV-exact-vns')



# Add labels and legend
plt.xlabel('Real Time')
plt.ylabel('FO')
plt.legend()
plt.title(f'Maternity p = {p} cover {cover} (51)')

# Save the plot as a PDF file
plt.savefig(f'maternity_plot_p_{p}_{cover}.pdf')

# Show the plot (optional)
plt.show()

# %%
df = df_mat_p_62_epci
p = 62
cover = 'epci'
# df.plot(x='time_exact', y='sol_exact', kind='line')
# plt.plot(df.exact_time, df.exact_sol, color='red', label='Exact',linestyle="--")
plt.plot(df.exact_TL_time, df.exact_TL_sol, color='red', label='Exact')
plt.plot(df.rssv_tbPMP_exact_time, df.rssv_tbPMP_exact_sol, color='blue', label='RSSV-exact')
# plt.plot(df.rssv_tbPMP_exact_vns_time, df.rssv_tbPMP_exact_vns_sol, color='green', label='RSSV-exact-vns')



# Add labels and legend
plt.xlabel('Real Time')
plt.ylabel('FO')
plt.legend()
plt.title(f'Maternity p = {p} cover {cover} (51)')

# Save the plot as a PDF file
plt.savefig(f'maternity_plot_p_{p}_{cover}.pdf')

# Show the plot (optional)
plt.show()

# %%
df = df_urgenc_p_42_arrond
p = 42
cover = 'arrond'
# df.plot(x='time_exact', y='sol_exact', kind='line')
# plt.plot(df.exact_time, df.exact_sol, color='red', label='Exact',linestyle="--")
plt.plot(df.exact_TL_time, df.exact_TL_sol, color='red', label='Exact')
plt.plot(df.rssv_tbPMP_exact_time, df.rssv_tbPMP_exact_sol, color='blue', label='RSSV-exact')
# plt.plot(df.rssv_tbPMP_exact_vns_time, df.rssv_tbPMP_exact_vns_sol, color='green', label='RSSV-exact-vns')



# Add labels and legend
plt.xlabel('Real Time')
plt.ylabel('FO')
plt.legend()
plt.title(f'Urgency p = {p} cover {cover} (18)')

# Save the plot as a PDF file
plt.savefig(f'urgency_plot_p_{p}_{cover}.pdf')

# Show the plot (optional)
plt.show()

# %%
df = df_urgenc_p_66_arrond
p = 66
cover = 'arrond'
# df.plot(x='time_exact', y='sol_exact', kind='line')
# plt.plot(df.exact_time, df.exact_sol, color='red', label='Exact',linestyle="--")
plt.plot(df.exact_TL_time, df.exact_TL_sol, color='red', label='Exact')
plt.plot(df.rssv_tbPMP_exact_time, df.rssv_tbPMP_exact_sol, color='blue', label='RSSV-exact')
# plt.plot(df.rssv_tbPMP_exact_vns_time, df.rssv_tbPMP_exact_vns_sol, color='green', label='RSSV-exact-vns')



# Add labels and legend
plt.xlabel('Real Time')
plt.ylabel('FO')
plt.legend()
plt.title(f'Urgency p = {p} cover {cover} (18)')

# Save the plot as a PDF file
plt.savefig(f'urgency_plot_p_{p}_{cover}.pdf')

# Show the plot (optional)
plt.show()

# %%
df = df_urgenc_p_54_epci
p = 54
cover = 'epci'
# df.plot(x='time_exact', y='sol_exact', kind='line')
# plt.plot(df.exact_time, df.exact_sol, color='red', label='Exact',linestyle="--")
plt.plot(df.exact_TL_time, df.exact_TL_sol, color='red', label='Exact')
plt.plot(df.rssv_tbPMP_exact_time, df.rssv_tbPMP_exact_sol, color='blue', label='RSSV-exact')
# plt.plot(df.rssv_tbPMP_exact_vns_time, df.rssv_tbPMP_exact_vns_sol, color='green', label='RSSV-exact-vns')



# Add labels and legend
plt.xlabel('Real Time')
plt.ylabel('FO')
plt.legend()
plt.title(f'Urgency p = {p} cover {cover} (51)')

# Save the plot as a PDF file
plt.savefig(f'urgency_plot_p_{p}_{cover}.pdf')

# Show the plot (optional)
plt.show()

# %%
df = df_urgenc_p_78_epci
p = 78
cover = 'epci'
# df.plot(x='time_exact', y='sol_exact', kind='line')
# plt.plot(df.exact_time, df.exact_sol, color='red', label='Exact',linestyle="--")
plt.plot(df.exact_TL_time, df.exact_TL_sol, color='red', label='Exact')
plt.plot(df.rssv_tbPMP_exact_time, df.rssv_tbPMP_exact_sol, color='blue', label='RSSV-exact')
# plt.plot(df.rssv_tbPMP_exact_vns_time, df.rssv_tbPMP_exact_vns_sol, color='green', label='RSSV-exact-vns')



# Add labels and legend
plt.xlabel('Real Time')
plt.ylabel('FO')
plt.legend()
plt.title(f'Urgency p = {p} cover {cover} (51)')

# Save the plot as a PDF file
plt.savefig(f'urgency_plot_p_{p}_{cover}.pdf')

# Show the plot (optional)
plt.show()

# %%
# Maternity cover Arrond.
service='Maternity'
cover='arrond'

# Sample data
values_exact = [97498258.810896873474121, 65204576.981497831642628, 64258450.848853193223476, 55220100.890514679253101,
                54244303.178164772689342,44028938.992577418684959,39818183.527719289064407, 37430123.114183843135834]
values_rssv_exact = [74455233.126443654298782, 63816069.942586608231068,55963819.613482803106308,50925859.703477121889591,
                     49066566.164376318454742,40634639.460162267088890,36912205.390405237674713,35287824.726925864815712]

values_rssv_exact_vns = [73942961.147262930870056, 65446135.279863320291042,56386163.457856044173241,49240597.486232660710812,
                     43772026.456217139959335,40634639.460162267088890,36912205.390405237674713,35287824.726925864815712]

p_values = [26, 30, 34, 38, 42, 46, 50, 54]

# Plot points and line with the same color
plt.plot(p_values, values_exact, color='red', marker='o', linestyle='-', label='Exact')
plt.plot(p_values, values_rssv_exact, color='blue', marker='o', linestyle='-', label='RSSV-exact')

# Add labels and title
plt.xlabel('Values of p')
plt.ylabel('Solution value')
plt.title(f'Solutions with differents values of p: {service} | {cover}')
plt.xticks(p_values) 
# Add legend
plt.legend()

# Save the plot as a PDF file
plt.savefig(f'maternity_plot_{cover}.pdf')

# Show plot
plt.show()

# %%
# Maternity.
service='Maternity'
cover='epci'

# Sample data
values_exact = [80598806.890420123934746, 63219873.756104126572609, 50509575.527299076318741, 42059051.215923093259335]
values_rssv_exact = [83053435.286300063133240, 63167686.972273871302605, 49690529.375281095504761, 41644058.703750424087048]

p_values = [51, 54, 58, 62]

# Plot points and line with the same color
plt.plot(p_values, values_exact, color='red', marker='o', linestyle='-', label='Exact')
plt.plot(p_values, values_rssv_exact, color='blue', marker='o', linestyle='-', label='RSSV-exact')

# Add labels and title
plt.xlabel('Values of p')
plt.ylabel('Solution value')
plt.title(f'Solutions with differents values of p: {service} | {cover}')
plt.xticks(p_values) 
# Add legend
plt.legend()

# Save the plot as a PDF file
plt.savefig(f'maternity_plot_{cover}.pdf')

# Show plot
plt.show()

# %%
# Urgency.
service='Urgency'
cover='arrond'

# Sample data
values_exact = [47985966.248153790831566, 42373186.871927678585052, 42083721.730802290141582, 37842841.971736773848534,
                35559332.047621294856071, 31683029.386743374168873,  29663093.955022260546684]
values_rssv_exact = [43815927.069372005760670, 41500876.554136425256729,38428759.676321595907211,34355216.490384064614773,
                32512304.404703769832850, 30662352.213462561368942, 29160547.216505020856857]

p_values = [42, 48, 54, 60, 66, 72, 78]

# Plot points and line with the same color
plt.plot(p_values, values_exact, color='red', marker='o', linestyle='-', label='Exact')
plt.plot(p_values, values_rssv_exact, color='blue', marker='o', linestyle='-', label='RSSV-exact')

# Add labels and title
plt.xlabel('Values of p')
plt.ylabel('Solution value')
plt.title(f'Solutions with differents values of p: {service} | {cover}')
plt.xticks(p_values) 
# Add legend
plt.legend()

# Save the plot as a PDF file
plt.savefig(f'urgency_plot_{cover}.pdf')

# Show plot
plt.show()

# %%
# Urgency.
service='Urgency'
cover='epci'

# Sample data
values_exact = [65778505.352574884891510, 45054352.222577258944511, 37089592.447383828461170,
                33572923.220917515456676, 31979354.146983534097672]
values_rssv_exact = [65377427.752062007784843, 45049107.311442121863365, 37005060.138388529419899,
                33582582.142353117465973, 31255355.724789626896381]

p_values = [54, 60, 66, 72, 78]

# Plot points and line with the same color
plt.plot(p_values, values_exact, color='red', marker='o', linestyle='-', label='Exact')
plt.plot(p_values, values_rssv_exact, color='blue', marker='o', linestyle='-', label='RSSV-exact')

# Add labels and title
plt.xlabel('Values of p')
plt.ylabel('Solution value')
plt.title(f'Solutions with differents values of p: {service} | {cover}')
plt.xticks(p_values) 
# Add legend
plt.legend()

# Save the plot as a PDF file
plt.savefig(f'urgency_plot_{cover}.pdf')

# Show plot
plt.show()
